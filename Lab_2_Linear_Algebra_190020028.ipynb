# %% [markdown]
#
# # Lab 2 : Linear Algebra
#
#   Solutions of the system of equations
#
# **There are missing fields in the code that you need to fill to get the results but note that you can write you own code to obtain the results**

# %%
## Import the required Libraries here
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# #Case 1 :

# %% [markdown]
# Consider an eqauation $A$**x**=**b** where A is a Full rank and square martrix, then the solution is given as ***x$_{op}$***=$A^{-1}$***b***, where ***x$_{op}$*** is the optimal solution and the error is given as ***b*** - $A$***x$_{op}$***
#
# Use the above information to solve the following equatation and compute the error  :
#
# $$x+y=5$$
# $$2x+4y=4$$

# %%
# Define Matrix A and B
A = [[1,1],[2,4]] # write your code here 
b =[[5],[4]]  # write your code here
print('A=',A,'\n')
print('b=',b,'\n')


# Determine the determinant of matrix A
Det = np.linalg.det(A) # write your code here
print('Determinant=',Det,'\n')

# Determine the rank of the matrix A
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the Inverse of matrix A
A_inverse = np.linalg.inv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse,b) # write your code here 
print('x=',x_op,'\n')

# Plot the equations
# write your code here
x = np.linspace(-10, 10, 1000)
y1 = 5 - x
y2 = 1 - x/2
plt.plot(x, y1)
plt.plot(x, y2)
plt.scatter(x_op[0], x_op[1])
# Validate the solution by obtaining the error
error = b- np.dot(A,x_op)  # write your code here 
print('error=',error,'\n')
# Out:
# A= [[1, 1], [2, 4]]
#
# b= [[5], [4]]
#
# Determinant= 2.0
#
# Matrix rank= 2
#
# A_inverse= [[ 2.  -0.5]
#  [-1.   0.5]]
#
# x= [[ 8.]
#  [-3.]]
#
# error= [[0.]
#  [0.]]

# %% [markdown]
# For the following equation :
#
# $$x+y+z=5$$
# $$2x+4y+z=4$$
# $$x+3y+4z=4$$
#
# Write the code to :
#   1. Define Matrices $A$ and $B$
#   2. Determine the determinant of $A$
#   3. Determine the rank of $A$
#   4. Determine the Inverse of matrix $A$
#   5. Determine the optimal solution
#   6. Plot the equations
#   7. Validate the solution by obataining error

# %%
from mpl_toolkits import mplot3d

# %%
## write your code here
A=np.array([[1,1,1],[2,4,1],[1,3,4]])
print('A :\n',A,'\n')
b=[[5],[4],[4]]
print('b : \n' , b ,'\n')
A_det=np.linalg.det(A)
print('Determinant of A : \n' , A_det,'\n')
A_rank=np.linalg.matrix_rank(A)
print('Rank of A : \n', A_rank,'\n')
A_inverse=np.linalg.inv(A)
print('A inverse = \n',A_inverse,'\n')
x_op=np.dot(A_inverse , b)
print('Optimal x : \n',x_op,'\n')

x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=5-X-Y
Z2=4-4*Y-2*X
Z3=(4-3*Y-X)/4
plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
#ax.plot(x_op[0],x_op[1],x_op[2],'o',color='m',markersize=100)
plt.show()
# Out:
# A :
#  [[1 1 1]
#  [2 4 1]
#  [1 3 4]]
#
# b :
#  [[5], [4], [4]]
#
# Determinant of A :
#  7.999999999999998
#
# Rank of A :
#  3
#
# A inverse =
#  [[ 1.625 -0.125 -0.375]
#  [-0.875  0.375  0.125]
#  [ 0.25  -0.25   0.25 ]]
#
# Optimal x :
#  [[ 6.125]
#  [-2.375]
#  [ 1.25 ]]

# %% [markdown]
# #Case 2 :

# %% [markdown]
# Consider an eqauation $A$**x**=**b** where A is a Full rank but it is not a square matrix ($m>n$, dimension of $A$ is $m*n$) , Here if $b$ lies in the span of columns of $A$ then there is unique solution and it is given as ***x$_{u}$***=$A^{-1}$***b*** (here $A^{-1}$ is the pseudo inverse of matrix A),  where ***x$_{u}$*** is the unique solution and the error is given as ***b*** - $A$***x$_{u}$***, If $b$ does not lie in the span of columns of $A$ then there are no solutions and the least square solution is given as ***x$_{ls}$***=$A^{-1}$***b*** (here $A^{-1}$ is the pseudo inverse of matrix A) and the error is given as ***b*** - $A$***x$_{ls}$***
#
# Use the above information solve the following equations and compute the error :
#
# $$x+z=0$$
# $$x+y+z=0$$
# $$y+z=0$$
# $$z=0$$

# %%
# Define matrix A and B
A =[[1,0,0],[1,1,1],[0,1,1],[0,0,1]]  # write your code here
b =[[0],[0],[0],[0]]  # write your code here
print('A=',A,'\n')
print('b=',b,'\n')

# Determine the rank of matrix A
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=\n',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.pinv(A) # write your code here
print('A_inverse=\n',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse,b) # write your code here 
print('x=\n',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=-X-0*Y
Z2=-X-Y
Z3=-Y-0*X
Z4=0*X-0*Y


plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.plot_surface(X,Y,Z4)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error= \n',error)
# Out:
# A= [[1, 0, 0], [1, 1, 1], [0, 1, 1], [0, 0, 1]]
#
# b= [[0], [0], [0], [0]]
#
# Matrix rank=
#  3
#
# A_inverse=
#  [[ 6.66666667e-01  3.33333333e-01 -3.33333333e-01  1.74172505e-16]
#  [-3.33333333e-01  3.33333333e-01  6.66666667e-01 -1.00000000e+00]
#  [ 2.43855683e-16  8.84770208e-17 -1.17436652e-16  1.00000000e+00]]
#
# x=
#  [[0.]
#  [0.]
#  [0.]]
# error=
#  [[0.]
#  [0.]
#  [0.]
#  [0.]]

# %% [markdown]
# For the following equation :
#
# $$x+y+z=35$$
# $$2x+4y+z=94$$
# $$x+3y+4z=4$$
# $$x+9y+4z=-230$$
#
# Write the code to :
#   1. Define Matrices $A$ and $B$
#   2. Determine the rank of $A$
#   3. Determine the Pseudo Inverse of matrix $A$
#   4. Determine the optimal solution
#   5. Plot the equations
#   6. Validate the solution by obataining error

# %%
# write your code here
A=[[1,1,1],[2,4,1],[1,3,4],[1,9,4]]
b=[[35],[94],[4],[-230]]
print('A = ')
print(A)
print('')

print('b = ')
print(b)
print('')

A_rank=np.linalg.matrix_rank(A)
print('Matrix rank= ') 
print(A_rank)
print('')

A_inverse=np.linalg.pinv(A)
print('A inverse= ')
print(A_inverse)
print('')

x_op=np.dot(A_inverse,b)
print('x_op= ')
print(x_op)
print('')

error= b-np.dot(A,x_op)
print('error= ')
print(error)
print('')

x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=35-X-Y
Z2=94-2*X-4*Y
Z3=(4-3*Y-X)/4
Z4=(-230-9*Y-X)/4

plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.plot_surface(X,Y,Z4)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# A =
# [[1, 1, 1], [2, 4, 1], [1, 3, 4], [1, 9, 4]]
#
# b =
# [[35], [94], [4], [-230]]
#
# Matrix rank=
# 3
#
# A inverse=
# [[ 0.27001704  0.45570698  0.07666099 -0.25809199]
#  [-0.06558773  0.02810903 -0.14480409  0.15417376]
#  [ 0.04429302 -0.16183986  0.31856899 -0.03918228]]
#
# x_op=
# [[111.9548552 ]
#  [-35.69250426]
#  [ -3.37649063]]
#
# error=
# [[-37.88586031]
#  [ 16.23679727]
#  [ 12.6286201 ]
#  [ -7.21635434]]

# %% [markdown]
# #Case 3 :

# %% [markdown]
# Consider an eqauation $A$**x**=**b** where A is not a Full rank matrix, Here if $b$ lies in the span of columns of $A$ then there are multiple solutions and one of the solution is given as ***x$_{u}$***=$A^{-1}$***b*** (here $A^{-1}$ is the pseudo inverse of matrix A), the error is given as ***b*** - $A$***x$_{u}$***, If $b$ does not lie in the span of columns of $A$ then there are no solutions and the least square solution is given as ***x$_{ls}$***=$A^{-1}$***b*** (here $A^{-1}$ is the pseudo inverse of matrix A) and the error is given as ***b*** - $A$***x$_{ls}$***
#
# Use the above information solve the following equations and compute the error :
#
# $$x+y+z=0$$
# $$3x+3y+3z=0$$
# $$x+2y+z=0$$

# %%
# Define matrix A and B
A = [[1,1,1],[3,3,3],[1,2,1]] # write your code here
b = [[0],[0],[0]] # write your code here
print('A=',A,'\n')
print('b=',b,'\n')

# Determine the rank of matrix A
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.pinv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse, b) # write your code here 
print('x_op=',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=-X-Y
Z2=(-3*X-3*Y)/3
Z3=(-2*Y-X)


plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error=',error,'\n')
# Out:
# A= [[1, 1, 1], [3, 3, 3], [1, 2, 1]]
#
# b= [[0], [0], [0]]
#
# Matrix rank= 2
#
# A_inverse= [[ 0.1  0.3 -0.5]
#  [-0.1 -0.3  1. ]
#  [ 0.1  0.3 -0.5]]
#
# x_op= [[0.]
#  [0.]
#  [0.]]
# error= [[0.]
#  [0.]
#  [0.]]

# %% [markdown]
# For the following equation :
#
# $$x+y+z=0$$
# $$3x+3y+3z=2$$
# $$x+2y+z=0$$
#
# Write the code to :
#   1. Define Matrices $A$ and $B$
#   2. Determine the rank of $A$
#   3. Determine the Pseudo Inverse of matrix $A$
#   4. Determine the optimal solution
#   5. Plot the equations
#   6. Validate the solution by obataining error

# %%
# write your code here
A=[[1,1,1],[3,3,3],[1,2,1]]
b=[[0],[2],[0]]

print('A=',A,'\n')
print('b=',b,'\n')
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.pinv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse, b) # write your code here 
print('x_op=',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=-X-Y
Z2=(-3*X-3*Y)/3
Z3=(-2*Y-X)


plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error=',error,'\n')
# Out:
# A= [[1, 1, 1], [3, 3, 3], [1, 2, 1]]
#
# b= [[0], [2], [0]]
#
# Matrix rank= 2
#
# A_inverse= [[ 0.1  0.3 -0.5]
#  [-0.1 -0.3  1. ]
#  [ 0.1  0.3 -0.5]]
#
# x_op= [[ 0.6]
#  [-0.6]
#  [ 0.6]]
# error= [[-6.0000000e-01]
#  [ 2.0000000e-01]
#  [-8.8817842e-16]]

# %% [markdown]
# # Examples

# %% [markdown]
# Find the solution for the below equations and justify the case that they belong to
#
# 1.$2x+3y+5z=2,9x+3y+2z=5,5x+9y+z=7$
#
# 2.$2x+3y=1,5x+9y=4,x+y=0$
#
# 3.$2x+5y+10z=0,9x+2y+z=1,4x+10y+20z=5$
#
# 4.$2x+3y=0,5x+9y=2,x+y=-2$
#
# 5.$2x+5y+3z=0,9x+2y+z=0,4x+10y+6z=0$

# %%
# write your code here
"""
2x+3y+5z=2
9x+3y+2z=5
5x+9y+z=7

"""

A=[[2,3,5],[9,3,2],[5,9,1]]
b=[[2],[5],[7]]

print('A=',A,'\n')
print('b=',b,'\n')
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.inv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse, b) # write your code here 
print('x_op=',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=(2-3*Y-2*X)/5
Z2=(5-9*X-3*Y)/2
Z3=(7-9*Y-5*X)


plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error=',error,'\n')
# Out:
# A= [[2, 3, 5], [9, 3, 2], [5, 9, 1]]
#
# b= [[2], [5], [7]]
#
# Matrix rank= 3
#
# A_inverse= [[-0.04950495  0.13861386 -0.02970297]
#  [ 0.00330033 -0.07590759  0.13531353]
#  [ 0.21782178 -0.00990099 -0.06930693]]
#
# x_op= [[ 0.38613861]
#  [ 0.57425743]
#  [-0.0990099 ]]
# error= [[4.4408921e-16]
#  [0.0000000e+00]
#  [8.8817842e-16]]

# %%
"""
2x+3y=1
5x+9y=4
x+y=0
"""
A=[[2,3],[5,9],[1,1]]
b=[[1],[4],[0]]

print('A=',A,'\n')
print('b=',b,'\n')
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.pinv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse, b) # write your code here 
print('x_op=',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y1=(1-2*x)/3
y2=(4-5*x)/9
y3=-x

plt1=plt.figure(figsize=(10,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error=',error,'\n')
# Out:
# A= [[2, 3], [5, 9], [1, 1]]
#
# b= [[1], [4], [0]]
#
# Matrix rank= 2
#
# A_inverse= [[ 1.         -0.5         1.5       ]
#  [-0.53846154  0.38461538 -0.84615385]]
#
# x_op= [[-1.]
#  [ 1.]]
# error= [[2.22044605e-15]
#  [5.32907052e-15]
#  [1.33226763e-15]]

# %%
"""
2x+5y+10z=0
9x+2y+z=1
4x+10y+20z=5
"""

A=[[2,5,10],[9,2,1],[4,10,20]]
b=[[0],[1],[5]]

print('A=',A,'\n')
print('b=',b,'\n')
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.pinv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse, b) # write your code here 
print('x_op=',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=(-5*Y-2*X)/10
Z2=(1-9*X-2*Y)/1
Z3=(5-10*Y-4*X)/20


plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error=',error,'\n')
# Out:
# A= [[2, 5, 10], [9, 2, 1], [4, 10, 20]]
#
# b= [[0], [1], [5]]
#
# Matrix rank= 2
#
# A_inverse= [[-0.00352332  0.11243523 -0.00704663]
#  [ 0.00733679  0.00704663  0.01467358]
#  [ 0.01703627 -0.02601036  0.03407254]]
#
# x_op= [[0.07720207]
#  [0.08041451]
#  [0.14435233]]
# error= [[-2.00000000e+00]
#  [-1.33226763e-15]
#  [ 1.00000000e+00]]

# %%
"""
2x+3y=0
5x+9y=2
x+y=−2
"""

A=[[2,3],[5,9],[1,1]]
b=[[0],[2],[-2]]

print('A=',A,'\n')
print('b=',b,'\n')
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.pinv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse, b) # write your code here 
print('x_op=',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y1=(-2*x)/3
y2=(2-5*x)/9
y3=-2-x

plt1=plt.figure(figsize=(10,10))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.scatter(x_op[0],x_op[1])
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error=',error,'\n')
# Out:
# A= [[2, 3], [5, 9], [1, 1]]
#
# b= [[0], [2], [-2]]
#
# Matrix rank= 2
#
# A_inverse= [[ 1.         -0.5         1.5       ]
#  [-0.53846154  0.38461538 -0.84615385]]
#
# x_op= [[-4.        ]
#  [ 2.46153846]]
# error= [[ 0.61538462]
#  [-0.15384615]
#  [-0.46153846]]

# %%
"""
2x+5y+3z=0
9x+2y+z=0
4x+10y+6z=0
"""


A=[[2,5,3],[9,2,1],[4,10,6]]
b=[[0],[0],[0]]

print('A=',A,'\n')
print('b=',b,'\n')
rank = np.linalg.matrix_rank(A) # write your code here
print('Matrix rank=',rank,'\n')

# Determine the pseudo-inverse of A (since A is not Square matrix)
A_inverse = np.linalg.pinv(A) # write your code here
print('A_inverse=',A_inverse,'\n')

# Determine the optimal solution
x_op = np.dot(A_inverse, b) # write your code here 
print('x_op=',x_op,'\n')

# Plot the equations
x=np.linspace(-10,10,1000)
y=np.linspace(-10,10,1000)
X,Y=np.meshgrid(x,y)
Z1=(-5*Y-2*X)/3
Z2=(-9*X-2*Y)/1
Z3=(-10*Y-4*X)/6


plt1=plt.figure(figsize=(10,10))
ax=plt.axes(projection='3d')
ax.plot_surface(X,Y,Z1)
ax.plot_surface(X,Y,Z2)
ax.plot_surface(X,Y,Z3)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Validate the solution by computing the error
error = b-np.dot(A,x_op) # write your code here 
print('error=',error,'\n')
# Out:
# A= [[2, 5, 3], [9, 2, 1], [4, 10, 6]]
#
# b= [[0], [0], [0]]
#
# Matrix rank= 2
#
# A_inverse= [[-0.00927612  0.12136974 -0.01855223]
#  [ 0.0319029  -0.03424361  0.06380581]
#  [ 0.01967924 -0.02384049  0.03935847]]
#
# x_op= [[0.]
#  [0.]
#  [0.]]
# error= [[0.]
#  [0.]
#  [0.]]
